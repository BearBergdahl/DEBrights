# %% [markdown]
# ## Control flows and loops
# * `while` and `for` loops.
# * `if`/`else` (and `elif`)
# * `try` - `except` (*often called try-catch from other languages, where you try and then catch an exception, Python defines the exception directly and skips a piece.*)
# * filehandling  `with open()`, and `open()` `close()`

# %%
# Control flows

a_list_of_lines = []
anumber = 79
while len(a_list_of_lines) == 0 :
    filename = input('Input filename: ')
    try:
        with open(filename) as afile:
            a_list_of_lines = afile.readlines()
            if len(a_list_of_lines)>anumber:
                print(a_list_of_lines[anumber])
    except (FileNotFoundError, IndexError):
        print('Wrong filename or to few lines in file, try again: ')

# %%
a_list_of_lines[45]
# Out:
# 'Milk: 2 tbs\n'

# %%
i = 0
while True:
    print('Oh so true!')
    i += 1
    if i == 5:
        print('Breaking out of loop')
        break
# Out:
# Oh so true!
# Oh so true!
# Oh so true!
# Oh so true!
# Oh so true!
# Breaking out of loop

# %% [markdown]
# * For-loops and different kind of iterables.
# * A quick dip into `chr()` [chars](https://www.w3schools.com/charsets/ref_html_ascii.asp)
#     Remember, Python 3 uses the expanded UTF-8. ASCII is an older, smaller set, but they are partially compatible of course.

# %%
for uneven in range(1,9,2):
    if uneven%3 != 0:
        print(uneven)
    else:
        print(f'This number is uneven {uneven} and divisible by 3: {uneven/2:.2f} and we have divided it in half')
  
for letter in 'banana':
    print(letter)

for fruit in ['banana', 'pineaple', 'kiwi']:
    for letter in fruit:
        print(letter)
# Out:
# 1
# This number is uneven 3 and divisible by 3: 1.50 and we have divided it in half
# 5
# 7
# b
# a
# n
# a
# n
# a
# b
# a
# n
# a
# n
# a
# p
# i
# n
# e
# a
# p
# l
# e
# k
# i
# w
# i
# Hello !
# Hello "
# Hello #
# Hello $
# Hello %
# Hello &
# Hello '
# Hello (
# Hello )
# Hello *
# Hello +
# Hello ,
# Hello -
# Hello .
# Hello /
# Hello 0
# Hello 1
# Hello 2
# Hello 3
# Hello 4
# Hello 5
# Hello 6
# Hello 7
# Hello 8
# Hello 9
# Hello :
# Hello ;
# Hello <
# Hello =
# Hello >
# Hello ?
# Hello @
# Hello A
# Hello B
# Hello C
# Hello D
# Hello E
# Hello F
# Hello G
# Hello H
# Hello I
# Hello J
# Hello K
# Hello L
# Hello M
# Hello N
# Hello O
# Hello P
# Hello Q
# Hello R
# Hello S
# Hello T
# Hello U
# Hello V
# Hello W
# Hello X
# Hello Y
# Hello Z
# Hello [
# Hello \
# Hello ]
# Hello ^
# Hello _
# Hello `
# Hello a
# Hello b
# Hello c
# Hello d
# Hello e
# Hello f
# Hello g
# Hello h
# Hello i
# Hello j
# Hello k
# Hello l
# Hello m
# Hello n
# Hello o
# Hello p
# Hello q
# Hello r
# Hello s
# Hello t
# Hello u
# Hello v
# Hello w
# Hello x
# Hello y
# Hello z
# Hello {
# Hello |
# Hello }
# Hello ~

# %% [markdown]
# ### Demo of chr

# %%
for i in range(33,127):
    print(f'Hello {chr(i)}')

# %% [markdown]
# Guard your inputs, if you need an int you can of course give instructions and hope for attentive users, but your best bet is not depending on dependeable users...

# %%
try:
    number = int(input('give me a number'))
    print(number)
except ValueError:
    print('oh no')
# Out:
# 5
